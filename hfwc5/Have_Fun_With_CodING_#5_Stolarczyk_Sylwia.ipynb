# %% [markdown]
# # Have Fun With CodING #5
# #####

# %% [markdown]
# # 1. Bitowy kopciuszek (200 pkt.)
#
# Kopciuszek dostał listę w której znajdują się elementy różnych typów. Są wśród nich typy: ```str, int, float, bool```. Zadanie polega na napisaniu kodu, który rozdzieli tą listę na poszczególne typy i całość zapisze w słowniku (zobacz przykłady)
#
# ```python
# # Przykład1
# input = [294, 119.28571428571429, False, 'qqzcipk8']
# output = {
#     'bool': [False],
#     'float': [119.28571428571429],
#     'int': [294],
#     'str': ['qqzcipk8']
# }
#
# # Przykład2
# input = [True, 'dwy692m5', 916, 31.142857142857142, 323, 88.28571428571429, '5t86uqk8', False, 'mspoz4zj', False, 572, 10.428571428571429]
# output = {
#     'bool': [True, False, False],
#     'float': [31.142857142857142, 88.28571428571429, 10.428571428571429],
#     'int': [916, 323, 572],
#     'str': ['dwy692m5', '5t86uqk8', 'mspoz4zj']
# }
# ```

# %%
input_list = [False, 944, False, '3wzwieh9', False, True, 131.0, 115.42857142857143, 134.42857142857142, 999, False, 15.428571428571429, 794, 40, 115, 15.285714285714286, True, 38.57142857142857, False, 'ypgwx259', 'ka5o82k0', 908, 'efrfumo8', 323, 2.857142857142857, False, 22.0, 'xuxvn01x', 100.85714285714286, True, False, False, 434, False, 86.14285714285714, 'bwua4ci9', 104.0, 53, 32.285714285714285, 72.14285714285714, '26v1awc1', 111.57142857142857, 73.14285714285714, False, True, True, 174, 'cjb6mtkw', False, 77.57142857142857, False, 'qljiafxk', 29.571428571428573, 534, True, True, 37, 60.285714285714285, 826, 'zctria7d', 184, 113.57142857142857, 'ybdkrg3t', 'hh6rw6y6', 130.71428571428572, 'ax9ra05x', 139.42857142857142, 492, 294, False, 465, True, False, True, '4vgqsnhc', True, 39.0, 380, 700, 136.85714285714286, False, True, 105.0, 33.0, True, False, 854, 'ke7vfyxe', 815, 'q90o0x4e', 'uiem4k5g', 'kdopsz7z', 37.714285714285715, 13.571428571428571, True, 'j25fzt46', True, 138.28571428571428, '25ljidwh', 40.142857142857146, 45.42857142857143, 'recddac5', 791, 'syh1y77d', 86, 932, True, 'djfnith1', 812, 130.0, 500, 104.57142857142857, True, 928, 376, 746, True, 73.14285714285714, 717, 91.42857142857143, 'atjxofnn', 108.57142857142857, 'yg8wmsy7', '13e4gegy', True, 16, 60.285714285714285, 110, False, '0hbzsg80', 736, True, 235, 782, True, 40.714285714285715, 17.571428571428573, 987, True, 80.14285714285714, True, False, False, 536, False, False, 'mq0s0z0x', 'vhigu6sy', '7u9hdues', 343, 2.0, 810, 892, False, 16, 660, False, 16.0, 'v0n8nec7', 18.142857142857142, '6x9eq4dh', True, 0.0, 'uy3dol9o', '6bldi1f1', True, False, 871, '0m8nek97', 45.0, 574, 36.42857142857143, 'u0yg81zj', 135.57142857142858, 316, False, 've19qzed', 141.85714285714286, 'wtp7p1y3', 91.14285714285714, True, 800, 908, 4.857142857142857, True, True, 73.28571428571429, 225, 'ichqkt10', True, 47.857142857142854, 982, 34, False, False, 179, 813, 'uiig
, False, 104.85714285714286, True, True, True, 'aczt0ygm', 448, 95.57142857142857, 'sryrw3j8', 762, '5tknshsy', 110.42857142857143, 646, 121.71428571428571, 758, 136.57142857142858, True, True, True, 889, 268, 54.42857142857143, 30.285714285714285, 109, False, 16.142857142857142, 153, 552, 50.714285714285715, False, 129.14285714285714, 918, True, 139.85714285714286, 117, True, '95yxbg4d', False, 'lfh78v2j', 16, 965, '4biedzts', 60.714285714285715, True, 109.57142857142857, 136.0, 16.142857142857142, True, 'uo6559g6', 431, True, 8.714285714285714, 116.57142857142857, 768, 'msli1peh', True, True, 112.42857142857143, False, 75.71428571428571, 30.571428571428573, False, 27.285714285714285, 628, True, True, 'znafln1j', 41.142857142857146, 'h5ipaqyp', True, 130.14285714285714, True, '7qwqhsfi', 91.57142857142857, 140.14285714285714, 258, 99.57142857142857, 168, False, True, 742, 765, 9.714285714285714, 235, 't95y1df1', False, 665, 'imbu1x2k', 'e4fvaals', '0iwtj3mb', False, 161, False, False, 470, 571, 514, 401, 'ka1f1f3r', '61tqneq2', 94, 'an77shbc', 'csei0qa8', 'slsbpmax', 245, 'm3qio8d2', False, 82.57142857142857, '6u1k2mvr', 447, False, 16, False, 'lf9m6fyy', 'vfc1993n', False, '0o1ri0t5', '5xfz3qb9', 211, 97.28571428571429, 57.0, 118.0, True, 22.428571428571427, 54.42857142857143, 56, False, 57.714285714285715, 'lgvu90zc', 96.71428571428571, 662, '4864sbr3', 605, 35.42857142857143, 82.14285714285714, 'eftj1iu6', 507, 89.57142857142857, 'mmjv0nn7', 'x0e55rth', 262, '09toh4ag', True, 575, 'yxwwdio7', 569, 100.71428571428571, 61.285714285714285, 133.0, 412, 136.42857142857142, 'ydt2it0r', '65yiakhe', 107.28571428571429, 265, 698, 50.714285714285715, 6.428571428571429, True, 375, 't9kog5bi', 274, 48.142857142857146, 28.571428571428573, 817, 18.428571428571427, True, 'bez3jno4', True, 20.714285714285715, 4.428571428571429, True, 97.57142857142857, 'a1ob3dln', True, 109.85714285714286, 18.714285714285715, False, False, 140]

# %%
import pprint
def hfwc1(input_list):
    output_dict = {'str': [], 'int': [], 'float': [], 'bool': []}

    for item in input_list:
        if isinstance(item, str):
            output_dict['str'].append(item)
        elif isinstance(item, float):
            output_dict['float'].append(item)
        elif isinstance(item, bool):
            output_dict['bool'].append(item)
        else:
            output_dict['int'].append(item)

    return output_dict


pprint.pprint(hfwc1(input_list))
# Out:
# {'bool': [False,
#           False,
#           False,
#           True,
#           False,
#           True,
#           False,
#           False,
#           True,
#           False,
#           False,
#           False,
#           False,
#           True,
#           True,
#           False,
#           False,
#           True,
#           True,
#           False,
#           True,
#           False,
#           True,
#           True,
#           False,
#           True,
#           True,
#           False,
#           True,
#           True,
#           True,
#           True,
#           True,
#           True,
#           False,
#           True,
#           True,
#           True,
#           True,
#           False,
#           False,
#           False,
#           False,
#           False,
#           False,
#           True,
#           True,
#           False,
#           False,
#           True,
#           True,
#           True,
#           True,
#           False,
# ...

# %% [markdown]
# # 2. Kantor (535 pkt.)
#
# Potrzeba napisać oprogramowanie do obsługi kantoru. Kantor ma tablicę z cenami poszczególnych walut ```price_table```, oraz określoną ilość gotówki w kasie w różnych walutach ```cash_register_data```. Praca kantoru polega na wykonywaniu transakcji kupna lub sprzedaży walut. Transakcja może się udać, lub nie być możliwa do wykonania z powodu zbyt małej ilości gotówki w kasie określonego typu (np. klient chce kupić 100USD a kantor ma tylko 80USD w kasie).
#
# Przykłady transakcji:
# ```python
# Transaction('BUY', 2800, 'CHF')
# # oznacza, że KANTOR KUPUJE 2800 Franków i wypłaca złotówki
#
# Transaction('SELL', 1200, 'USD')
# # oznacza, że KANTOR SPRZEDAJE 1200 Dolarów i przyjmuje złotówki
# ```
#
# Dane wejściowe:
# - **price_table** - tablica cen kupna / sprzedaży - pierwsza w tupli cena po której kantor kupuje, druga - po której sprzedaje
# - **cash_register_data** - zawartość kasy - ilości poszczególnych walut w kasie
# - **transactions** - lista transakcji do wykonania
#
# Algorytm powinien:
# - podjąć próbę wykonania transakcji z listy po kolei
# - zwrócić listę transakcji, które można wykonać
# - zwrócić ilość transakcji, które można wykonać
# - zwrócić listę transakcji, których nie można wykonać
# - zwrócić ilość transakcji, których nie można wykonać
# - zwrócić stan kasy po wykonaniu możliwych do wykonania transakcji
#
# ### Zobacz przykład:
#
# ```python
# price_table = {'EUR': (4.5088, 4.5998), 'USD': (3.8752, 3.9534)}
#
# cash_register_data = {'EUR': 10000, 'USD': 10000, 'PLN': 1000}
#
# transactions = [
#     Transaction('SELL', 4300, 'EUR'),
#     Transaction('BUY', 300, 'EUR'),
#     Transaction('BUY', 2500, 'USD'),
#     Transaction('BUY', 2300, 'EUR'),
#     Transaction('BUY', 400, 'USD')]
#
# Trying to make transaction #0 (Transaction('SELL', 4300, 'EUR'))
# Transaction possible. Processing.
# # Mamy w kasie 10.000 EUR a chcemy sprzedać 4300
# Deposit 19779.14 PLN to cash register
# # [4300 EUR = 4300 * 4.5998 = 19779.14 PLN] - klient płaci 19779.14 PLN ...
# Withdraw 4300 EUR from cash register
# # ... i otrzymuje 4300 EUR z kasy kantoru
# # Analogicznie dla następnych transakcji.
# ############################
# Trying to make transaction #1 (Transaction('BUY', 300, 'EUR'))
# Transaction possible. Processing.
# Deposit 300 EUR to cash register
# Withdraw 1352.6399999999999 PLN from cash register
# ############################
# Trying to make transaction #2 (Transaction('BUY', 2500, 'USD'))
# Transaction possible. Processing.
# Deposit 2500 USD to cash register
# Withdraw 9688.0 PLN from cash register
# ############################
# Trying to make transaction #3 (Transaction('BUY', 2300, 'EUR'))
# Transaction NOT possible! Trying next one.
# # Ta transakcja nie jest możliwa - zabrakło PLN, aby kupić 2300 EUR.
# # W kasie jest w tym momencie 9738.5 PLN, a potrzeba [2300 * 4.5088] = 10370.24 PLN
# ############################
# Trying to make transaction #4 (Transaction('BUY', 400, 'USD'))
# Transaction possible. Processing.
# Deposit 400 USD to cash register
# Withdraw 1550.08 PLN from cash register
# ############################
# ############################
# ############################
# Rozwiązanie:
# Stan kasy po wykonaniu wszystkich możliwych do wykonania transakcji
# {'EUR': 6000, 'USD': 12900, 'PLN': 8188.42}
#
# Transakcje udane:
# Success transactions: [(Transaction('SELL', 4300, 'EUR'), 'OK'), (Transaction('BUY', 300, 'EUR'), 'OK'), (Transaction('BUY', 2500, 'USD'), 'OK'), (Transaction('BUY', 400, 'USD'), 'OK')]
#
# Transakcje nieudane:
# Failed transactions: [(Transaction('BUY', 2300, 'EUR'), 'Not enough money [PLN]. 9738.5 < 10370.24')]
# ```

# %% [markdown]
# ### Rozwiąż zadanie w poniższej komórce
# #### Zasady:
# - uzupełnij kod we wskazanych miejscach
# - nie zmieniaj struktury
# - jeśli potrzeba, można dopisać dodatkowe metody
# - poprawność rozwiązania można sprawdzić w kolejnej komórce

# %%
class Transaction:
    def __init__(self, transaction_type, amount, currency):
        self.transaction_type = transaction_type
        self.amount = amount
        self.currency = currency

    def __repr__(self):
        return f"Transaction('{self.transaction_type}', {self.amount}, '{self.currency}')"


class CashRegister:
    def __init__(self, cash_register_data):
        self.cash_register_data = cash_register_data

    def deposit(self, currency, amount):
        self.cash_register_data[currency] += amount
        print (f"Deposit {amount} {currency} to cash register" )

    def withdraw(self, currency, amount):
        self.cash_register_data[currency] -= amount
        print (f"Withdraw {amount} {currency} from cash register")

    def print_cash_report(self):
        print(self.cash_register_data)



class MoneyExchange:
    def __init__(self, price_table, cash_register):
        self.price_table = price_table
        self.cash_register = cash_register
        self.success_transactions = []
        self.failed_transactions = []

    def make_transaction(self, transaction):
        if self.is_possible(transaction):
            print(f"Transaction possible. Processing.") 
            if transaction.transaction_type == 'BUY':
                self.cash_register.deposit(transaction.currency, transaction.amount)
                self.cash_register.withdraw('PLN', self.calculate_price(transaction))
            elif transaction.transaction_type == 'SELL':
                self.cash_register.deposit('PLN', self.calculate_price(transaction))
                self.cash_register.withdraw(transaction.currency, transaction.amount)
            self.success_transactions.append((transaction, 'OK'))
        else:
            available_amount = self.cash_register.cash_register_data[transaction.currency]
            required_amount = self.calculate_price(transaction)
            print('Transaction NOT possible! Trying next one.')
            self.failed_transactions.append((transaction, f"Not enough money [{transaction.currency}]. {available_amount} < {required_amount}"))
    
    def print_report(self):
        print("Rozwiązanie:")
        print("Stan kasy po wykonaniu wszystkich możliwych do wykonania transakcji")
        print(self.cash_register.cash_register_data)
        print("\nTransakcje udane:")
        print("Success transactions:", [f"{transaction} - {status}" for transaction, status in self.success_transactions])
        print("Total =", len(self.success_transactions))
        print("\nTransakcje nieudane:")
        print("Failed transactions:", [f"{transaction} - {reason}" for transaction, reason in self.failed_transactions])
        print("Total =", len(self.failed_transactions))

    def is_possible(self, transaction):
        if transaction.transaction_type == 'BUY':
            price = self.price_table[transaction.currency][0] * transaction.amount
            return price <= self.cash_register.cash_register_data['PLN']
        elif transaction.transaction_type == 'SELL':
            return transaction.amount <= self.cash_register.cash_register_data[transaction.currency]

    def calculate_price(self, transaction):
        if transaction.transaction_type == 'BUY':
            return self.price_table[transaction.currency][0] * transaction.amount
        elif transaction.transaction_type == 'SELL':
            return self.price_table[transaction.currency][1] * transaction.amount

   
# Dane wejściowe
price_table = {'EUR': (4.5088, 4.5998),
                   'USD': (3.8752, 3.9534),
                   'GBP': (4.9273, 5.0269),
                   'CZK': (0.1662, 0.1696),
                   'CHF': (4.1727, 4.2569)}

cash_register_data = {'EUR': 10000,
                          'USD': 10000,
                          'GBP': 10000,
                          'CZK': 100000,
                          'CHF': 10000,
                          'PLN': 100000}

transactions = [Transaction('BUY', 300, 'GBP'), Transaction('BUY', 800, 'GBP'), Transaction('BUY', 200, 'CZK'), Transaction('SELL', 200, 'USD'), Transaction('BUY', 800, 'USD'), Transaction('BUY', 1000, 'USD'), Transaction('SELL', 800, 'EUR'), Transaction('BUY', 1000, 'CHF'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 400, 'EUR'), Transaction('BUY', 1000, 'GBP'), Transaction('SELL', 400, 'CHF'), Transaction('SELL', 700, 'CHF'), Transaction('BUY', 200, 'CZK'), Transaction('BUY', 300, 'EUR'), Transaction('BUY', 1000, 'USD'), Transaction('SELL', 300, 'CZK'), Transaction('BUY', 100, 'EUR'), Transaction('SELL', 800, 'CHF'), Transaction('SELL', 1000, 'GBP'), Transaction('BUY', 800, 'USD'), Transaction('BUY', 300, 'GBP'), Transaction('SELL', 200, 'USD'), Transaction('BUY', 800, 'EUR'), Transaction('SELL', 500, 'GBP'), Transaction('SELL', 700, 'USD'), Transaction('SELL', 900, 'USD'), Transaction('BUY', 700, 'USD'), Transaction('SELL', 400, 'USD'), Transaction('SELL', 900, 'EUR'), Transaction('SELL', 600, 'EUR'), Transaction('BUY', 1000, 'GBP'), Transaction('SELL', 1000, 'CZK'), Transaction('BUY', 700, 'CHF'), Transaction('BUY', 1000, 'USD'), Transaction('BUY', 100, 'GBP'), Transaction('BUY', 500, 'GBP'), Transaction('BUY', 600, 'EUR'), Transaction('BUY', 200, 'EUR'), Transaction('BUY', 900, 'USD'), Transaction('BUY', 100, 'USD'), Transaction('BUY', 500, 'GBP'), Transaction('BUY', 500, 'CHF'), Transaction('BUY', 800, 'CZK'), Transaction('SELL', 600, 'EUR'), Transaction('SELL', 1000, 'EUR'), Transaction('SELL', 600, 'USD'), Transaction('BUY', 700, 'CHF'), Transaction('SELL', 100, 'USD'), Transaction('SELL', 1000, 'USD'), Transaction('SELL', 100, 'USD'), Transaction('SELL', 200, 'CHF'), Transaction('SELL', 100, 'CZK'), Transaction('SELL', 200, 'GBP'), Transaction('SELL', 900, 'EUR'), Transaction('SELL', 1000, 'USD'), Transaction('BUY', 1000, 'GBP'), Transaction('BUY', 200, 'CHF'), Transaction('SELL', 700, 'CHF'), Transaction('BUY', 200, 'CHF'), Transaction('SELL', 700, 'EUR'), Transaction('BUY', 500, 'CZK'), Transaction('SELL', 400, 'USD'), Transaction('SELL', 900, 'EUR'), Transaction('SELL', 300, 'USD'), Transaction('SELL', 200, 'CZK'), Transaction('BUY', 800, 'CZK'), Transaction('BUY', 300, 'CHF'), Transaction('SELL', 600, 'EUR'), Transaction('SELL', 300, 'GBP'), Transaction('SELL', 100, 'CHF'), Transaction('SELL', 400, 'EUR'), Transaction('BUY', 600, 'USD'), Transaction('SELL', 200, 'CZK'), Transaction('BUY', 900, 'CHF'), Transaction('BUY', 700, 'USD'), Transaction('BUY', 1000, 'CZK'), Transaction('SELL', 400, 'GBP'), Transaction('BUY', 400, 'GBP'), Transaction('BUY', 400, 'EUR'), Transaction('BUY', 400, 'CHF'), Transaction('BUY', 800, 'GBP'), Transaction('BUY', 1000, 'EUR'), Transaction('SELL', 800, 'EUR'), Transaction('BUY', 900, 'CHF'), Transaction('BUY', 500, 'EUR'), Transaction('SELL', 900, 'GBP'), Transaction('SELL', 1000, 'CZK'), Transaction('SELL', 800, 'EUR'), Transaction('SELL', 200, 'USD'), Transaction('SELL', 900, 'GBP'), Transaction('SELL', 400, 'EUR'), Transaction('SELL', 800, 'GBP'), Transaction('BUY', 700, 'GBP'), Transaction('BUY', 1000, 'GBP'), Transaction('BUY', 700, 'USD'), Transaction('BUY', 900, 'EUR'), Transaction('BUY', 400, 'USD'), Transaction('BUY', 600, 'EUR'), Transaction('SELL', 800, 'CHF'), Transaction('BUY', 700, 'CZK'), Transaction('SELL', 600, 'USD'), Transaction('BUY', 400, 'USD'), Transaction('BUY', 800, 'EUR'), Transaction('BUY', 600, 'EUR'), Transaction('SELL', 100, 'EUR'), Transaction('BUY', 700, 'CZK'), Transaction('BUY', 500, 'EUR'), Transaction('SELL', 600, 'USD'), Transaction('BUY', 400, 'USD'), Transaction('BUY', 600, 'CHF'), Transaction('BUY', 400, 'GBP'), Transaction('SELL', 100, 'USD'), Transaction('BUY', 100, 'CHF'), Transaction('SELL', 900, 'EUR'), Transaction('SELL', 100, 'USD'), Transaction('SELL', 400, 'EUR'), Transaction('SELL', 1000, 'EUR'), Transaction('SELL', 400, 'CHF'), Transaction('SELL', 800, 'GBP'), Transaction('SELL', 400, 'USD'), Transaction('SELL', 800, 'GBP'), Transaction('BUY', 400, 'USD'), Transaction('BUY', 900, 'GBP'), Transaction('BUY', 500, 'USD'), Transaction('SELL', 400, 'CZK'), Transaction('BUY', 100, 'EUR'), Transaction('SELL', 900, 'GBP'), Transaction('BUY', 800, 'CHF'), Transaction('SELL', 300, 'CHF'), Transaction('BUY', 300, 'EUR'), Transaction('SELL', 500, 'CHF'), Transaction('BUY', 800, 'CZK'), Transaction('BUY', 400, 'CZK'), Transaction('BUY', 100, 'EUR'), Transaction('BUY', 100, 'GBP'), Transaction('SELL', 1000, 'CZK'), Transaction('BUY', 200, 'GBP'), Transaction('SELL', 300, 'CHF'), Transaction('BUY', 600, 'GBP'), Transaction('SELL', 500, 'CZK'), Transaction('BUY', 1000, 'CHF'), Transaction('BUY', 600, 'CZK'), Transaction('BUY', 800, 'EUR'), Transaction('BUY', 400, 'GBP'), Transaction('SELL', 200, 'CHF'), Transaction('BUY', 400, 'CZK'), Transaction('SELL', 900, 'EUR'), Transaction('BUY', 200, 'CHF'), Transaction('BUY', 1000, 'EUR'), Transaction('SELL', 900, 'GBP'), Transaction('BUY', 900, 'GBP'), Transaction('BUY', 900, 'EUR'), Transaction('SELL', 200, 'CZK'), Transaction('BUY', 600, 'CZK'), Transaction('SELL', 100, 'CHF'), Transaction('BUY', 500, 'GBP'), Transaction('SELL', 500, 'EUR'), Transaction('BUY', 400, 'GBP'), Transaction('BUY', 800, 'CZK'), Transaction('SELL', 400, 'CHF'), Transaction('SELL', 200, 'CHF'), Transaction('SELL', 300, 'CZK'), Transaction('SELL', 300, 'CHF'), Transaction('SELL', 400, 'CHF'), Transaction('BUY', 900, 'GBP'), Transaction('BUY', 700, 'EUR'), Transaction('SELL', 700, 'CHF'), Transaction('SELL', 400, 'EUR'), Transaction('SELL', 300, 'EUR'), Transaction('SELL', 600, 'CHF'), Transaction('BUY', 400, 'EUR'), Transaction('BUY', 100, 'USD'), Transaction('SELL', 200, 'CHF'), Transaction('BUY', 100, 'EUR'), Transaction('SELL', 400, 'EUR'), Transaction('BUY', 400, 'CZK'), Transaction('BUY', 200, 'CZK'), Transaction('SELL', 100, 'USD'), Transaction('SELL', 200, 'CHF'), Transaction('BUY', 700, 'USD'), Transaction('SELL', 300, 'CZK'), Transaction('BUY', 200, 'CHF'), Transaction('BUY', 100, 'EUR'), Transaction('SELL', 400, 'CHF'), Transaction('BUY', 800, 'CZK'), Transaction('BUY', 800, 'EUR'), Transaction('SELL', 1000, 'USD'), Transaction('SELL', 700, 'USD'), Transaction('SELL', 1000, 'CHF'), Transaction('BUY', 600, 'GBP'), Transaction('SELL', 300, 'USD'), Transaction('SELL', 600, 'GBP'), Transaction('BUY', 300, 'USD'), Transaction('BUY', 700, 'CHF'), Transaction('BUY', 800, 'GBP'), Transaction('SELL', 900, 'CHF'), Transaction('BUY', 700, 'USD'), Transaction('SELL', 600, 'CZK'), Transaction('BUY', 800, 'CZK'), Transaction('BUY', 800, 'EUR'), Transaction('BUY', 200, 'EUR'), Transaction('BUY', 500, 'CHF'), Transaction('BUY', 600, 'CHF'), Transaction('SELL', 700, 'GBP'), Transaction('BUY', 800, 'GBP'), Transaction('BUY', 400, 'GBP'), Transaction('SELL', 400, 'CZK'), Transaction('SELL', 900, 'CZK'), Transaction('SELL', 700, 'GBP'), Transaction('SELL', 400, 'CZK'), Transaction('BUY', 100, 'USD'), Transaction('SELL', 200, 'GBP'), Transaction('BUY', 800, 'GBP'), Transaction('SELL', 1000, 'CZK'), Transaction('SELL', 800, 'GBP'), Transaction('SELL', 900, 'USD'), Transaction('BUY', 700, 'GBP'), Transaction('BUY', 500, 'CHF'), Transaction('BUY', 100, 'USD'), Transaction('BUY', 400, 'GBP'), Transaction('SELL', 1000, 'GBP'), Transaction('BUY', 800, 'GBP'), Transaction('SELL', 700, 'USD'), Transaction('BUY', 300, 'CZK'), Transaction('BUY', 1000, 'CZK'), Transaction('BUY', 700, 'CZK'), Transaction('BUY', 400, 'GBP'), Transaction('BUY', 500, 'CZK'), Transaction('BUY', 600, 'CHF'), Transaction('SELL', 100, 'USD'), Transaction('BUY', 500, 'CZK'), Transaction('SELL', 100, 'USD'), Transaction('BUY', 400, 'CZK'), Transaction('BUY', 600, 'CZK'), Transaction('BUY', 300, 'USD'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 700, 'GBP'), Transaction('SELL', 400, 'CZK'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 800, 'EUR'), Transaction('SELL', 700, 'CHF'), Transaction('SELL', 300, 'USD'), Transaction('BUY', 400, 'CHF'), Transaction('SELL', 800, 'GBP'), Transaction('BUY', 600, 'CHF'), Transaction('SELL', 700, 'GBP'), Transaction('SELL', 500, 'CZK'), Transaction('BUY', 700, 'CZK'), Transaction('SELL', 400, 'CZK'), Transaction('BUY', 800, 'EUR'), Transaction('SELL', 100, 'USD'), Transaction('SELL', 100, 'CHF'), Transaction('SELL', 900, 'EUR'), Transaction('BUY', 800, 'EUR'), Transaction('BUY', 100, 'GBP'), Transaction('BUY', 500, 'CZK'), Transaction('BUY', 100, 'CZK'), Transaction('SELL', 200, 'EUR'), Transaction('BUY', 200, 'EUR'), Transaction('SELL', 400, 'CHF'), Transaction('BUY', 400, 'CZK'), Transaction('SELL', 1000, 'CZK'), Transaction('BUY', 200, 'CZK'), Transaction('BUY', 500, 'CHF'), Transaction('SELL', 300, 'CZK'), Transaction('SELL', 600, 'USD'), Transaction('BUY', 100, 'EUR'), Transaction('SELL', 500, 'GBP'), Transaction('SELL', 700, 'EUR'), Transaction('BUY', 300, 'USD'), Transaction('SELL', 1000, 'EUR'), Transaction('BUY', 100, 'CHF'), Transaction('BUY', 900, 'EUR'), Transaction('BUY', 500, 'EUR'), Transaction('BUY', 400, 'GBP'), Transaction('BUY', 300, 'EUR'), Transaction('SELL', 900, 'GBP'), Transaction('BUY', 300, 'GBP'), Transaction('SELL', 700, 'USD'), Transaction('BUY', 1000, 'USD'), Transaction('BUY', 300, 'CZK'), Transaction('BUY', 400, 'CZK'), Transaction('SELL', 300, 'CZK'), Transaction('SELL', 100, 'CHF'), Transaction('BUY', 400, 'EUR'), Transaction('SELL', 100, 'CZK'), Transaction('SELL', 100, 'USD'), Transaction('BUY', 900, 'CZK'), Transaction('SELL', 400, 'EUR'), Transaction('BUY', 800, 'CHF'), Transaction('SELL', 100, 'EUR'), Transaction('BUY', 1000, 'CHF'), Transaction('SELL', 700, 'EUR'), Transaction('SELL', 900, 'CZK'), Transaction('SELL', 400, 'GBP'), Transaction('BUY', 700, 'CHF'), Transaction('SELL', 1000, 'GBP'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 100, 'GBP'), Transaction('SELL', 100, 'CHF'), Transaction('BUY', 1000, 'GBP'), Transaction('BUY', 300, 'GBP'), Transaction('SELL', 500, 'GBP'), Transaction('SELL', 800, 'USD'), Transaction('SELL', 600, 'CHF'), Transaction('BUY', 100, 'CHF'), Transaction('SELL', 200, 'USD'), Transaction('SELL', 600, 'GBP'), Transaction('BUY', 1000, 'USD'), Transaction('BUY', 800, 'USD'), Transaction('SELL', 300, 'USD'), Transaction('SELL', 700, 'CHF'), Transaction('BUY', 900, 'CHF'), Transaction('SELL', 1000, 'EUR'), Transaction('BUY', 900, 'EUR'), Transaction('BUY', 200, 'USD'), Transaction('BUY', 100, 'GBP'), Transaction('BUY', 900, 'GBP'), Transaction('BUY', 200, 'CZK'), Transaction('BUY', 300, 'EUR'), Transaction('BUY', 300, 'EUR'), Transaction('BUY', 1000, 'CHF'), Transaction('BUY', 500, 'GBP'), Transaction('SELL', 400, 'USD'), Transaction('BUY', 800, 'EUR'), Transaction('BUY', 100, 'CZK'), Transaction('BUY', 400, 'CZK'), Transaction('BUY', 100, 'USD'), Transaction('SELL', 900, 'USD'), Transaction('SELL', 1000, 'CZK'), Transaction('BUY', 100, 'EUR'), Transaction('BUY', 400, 'CHF'), Transaction('SELL', 200, 'EUR'), Transaction('BUY', 800, 'EUR'), Transaction('SELL', 600, 'USD'), Transaction('SELL', 800, 'GBP'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 700, 'CHF'), Transaction('SELL', 200, 'GBP'), Transaction('BUY', 800, 'GBP'), Transaction('BUY', 600, 'EUR'), Transaction('SELL', 400, 'GBP'), Transaction('SELL', 400, 'EUR'), Transaction('SELL', 300, 'EUR'), Transaction('BUY', 600, 'CZK'), Transaction('BUY', 600, 'CHF'), Transaction('SELL', 1000, 'GBP'), Transaction('BUY', 500, 'CZK'), Transaction('SELL', 200, 'GBP'), Transaction('SELL', 600, 'CHF'), Transaction('BUY', 800, 'EUR'), Transaction('SELL', 300, 'CHF'), Transaction('SELL', 600, 'USD'), Transaction('SELL', 300, 'EUR'), Transaction('BUY', 1000, 'USD'), Transaction('SELL', 700, 'EUR'), Transaction('BUY', 700, 'USD'), Transaction('SELL', 700, 'GBP'), Transaction('BUY', 600, 'CZK'), Transaction('SELL', 900, 'CZK'), Transaction('SELL', 500, 'CZK'), Transaction('BUY', 100, 'CZK'), Transaction('BUY', 900, 'GBP'), Transaction('BUY', 900, 'CHF'), Transaction('SELL', 1000, 'CHF'), Transaction('SELL', 400, 'USD'), Transaction('BUY', 900, 'CHF'), Transaction('SELL', 100, 'CZK'), Transaction('SELL', 1000, 'EUR'), Transaction('SELL', 300, 'GBP'), Transaction('BUY', 1000, 'GBP'), Transaction('SELL', 700, 'CHF'), Transaction('BUY', 600, 'USD'), Transaction('BUY', 100, 'CHF'), Transaction('SELL', 700, 'CHF'), Transaction('SELL', 900, 'EUR'), Transaction('SELL', 400, 'CHF'), Transaction('BUY', 200, 'CHF'), Transaction('BUY', 1000, 'USD'), Transaction('BUY', 600, 'USD'), Transaction('BUY', 300, 'CZK'), Transaction('SELL', 300, 'CHF'), Transaction('SELL', 100, 'EUR'), Transaction('BUY', 800, 'USD'), Transaction('BUY', 900, 'CZK'), Transaction('BUY', 800, 'CZK'), Transaction('BUY', 200, 'CZK'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 300, 'EUR'), Transaction('BUY', 200, 'CHF'), Transaction('SELL', 800, 'EUR'), Transaction('BUY', 900, 'CZK'), Transaction('SELL', 400, 'EUR'), Transaction('BUY', 800, 'CZK'), Transaction('BUY', 300, 'GBP'), Transaction('SELL', 1000, 'CHF'), Transaction('SELL', 600, 'USD'), Transaction('BUY', 500, 'EUR'), Transaction('SELL', 1000, 'CHF'), Transaction('BUY', 700, 'CHF'), Transaction('BUY', 800, 'CZK'), Transaction('BUY', 200, 'CHF'), Transaction('BUY', 900, 'CZK'), Transaction('SELL', 300, 'CHF'), Transaction('SELL', 600, 'USD'), Transaction('SELL', 900, 'GBP'), Transaction('SELL', 300, 'EUR'), Transaction('BUY', 300, 'EUR'), Transaction('SELL', 800, 'CHF'), Transaction('SELL', 400, 'USD'), Transaction('SELL', 300, 'EUR'), Transaction('BUY', 500, 'GBP'), Transaction('SELL', 300, 'EUR'), Transaction('SELL', 500, 'CHF'), Transaction('BUY', 100, 'GBP'), Transaction('BUY', 400, 'CZK'), Transaction('SELL', 800, 'CHF'), Transaction('BUY', 400, 'CHF'), Transaction('BUY', 500, 'CHF'), Transaction('BUY', 300, 'EUR'), Transaction('BUY', 800, 'CHF'), Transaction('SELL', 100, 'USD'), Transaction('BUY', 800, 'CZK'), Transaction('SELL', 1000, 'GBP'), Transaction('BUY', 300, 'EUR'), Transaction('SELL', 300, 'CHF'), Transaction('BUY', 100, 'EUR'), Transaction('SELL', 400, 'GBP'), Transaction('SELL', 800, 'EUR'), Transaction('SELL', 200, 'EUR'), Transaction('BUY', 1000, 'CZK'), Transaction('SELL', 700, 'USD'), Transaction('SELL', 200, 'GBP'), Transaction('SELL', 900, 'CHF'), Transaction('BUY', 700, 'CHF'), Transaction('BUY', 700, 'GBP'), Transaction('SELL', 300, 'CZK'), Transaction('SELL', 900, 'CZK'), Transaction('BUY', 400, 'GBP'), Transaction('SELL', 200, 'CHF'), Transaction('SELL', 1000, 'CHF'), Transaction('BUY', 900, 'CHF'), Transaction('BUY', 500, 'EUR'), Transaction('BUY', 600, 'CHF'), Transaction('SELL', 100, 'USD'), Transaction('SELL', 800, 'EUR'), Transaction('BUY', 200, 'USD'), Transaction('SELL', 300, 'USD'), Transaction('BUY', 1000, 'USD'), Transaction('SELL', 400, 'CZK'), Transaction('SELL', 1000, 'CZK'), Transaction('SELL', 700, 'USD'), Transaction('BUY', 500, 'CZK'), Transaction('BUY', 700, 'USD'), Transaction('BUY', 1000, 'USD'), Transaction('SELL', 600, 'GBP'), Transaction('SELL', 100, 'CZK'), Transaction('SELL', 700, 'GBP'), Transaction('SELL', 300, 'CHF'), Transaction('SELL', 200, 'EUR'), Transaction('BUY', 200, 'GBP'), Transaction('BUY', 1000, 'CZK'), Transaction('BUY', 300, 'USD'), Transaction('BUY', 200, 'EUR'), Transaction('BUY', 1000, 'CHF'), Transaction('BUY', 100, 'EUR'), Transaction('BUY', 600, 'CHF'), Transaction('SELL', 500, 'EUR'), Transaction('SELL', 1000, 'GBP'), Transaction('SELL', 100, 'GBP'), Transaction('SELL', 200, 'GBP'), Transaction('SELL', 800, 'CHF'), Transaction('BUY', 400, 'EUR'), Transaction('SELL', 800, 'GBP'), Transaction('SELL', 500, 'USD'), Transaction('BUY', 100, 'CHF'), Transaction('BUY', 1000, 'CHF'), Transaction('SELL', 700, 'CZK'), Transaction('SELL', 700, 'CZK'), Transaction('BUY', 100, 'EUR'), Transaction('SELL', 700, 'CHF'), Transaction('SELL', 800, 'GBP'), Transaction('BUY', 900, 'EUR'), Transaction('SELL', 200, 'CZK'), Transaction('BUY', 600, 'CZK'), Transaction('SELL', 900, 'GBP'), Transaction('SELL', 1000, 'CHF'), Transaction('BUY', 700, 'CHF'), Transaction('BUY', 300, 'EUR'), Transaction('BUY', 700, 'EUR'), Transaction('SELL', 900, 'CZK'), Transaction('BUY', 400, 'GBP'), Transaction('SELL', 500, 'EUR'), Transaction('SELL', 100, 'CZK'), Transaction('SELL', 700, 'USD'), Transaction('SELL', 400, 'EUR'), Transaction('BUY', 1000, 'USD'), Transaction('BUY', 200, 'EUR'), Transaction('SELL', 600, 'CZK'), Transaction('BUY', 600, 'EUR'), Transaction('SELL', 600, 'USD'), Transaction('BUY', 200, 'CHF'), Transaction('SELL', 200, 'CZK'), Transaction('SELL', 800, 'GBP'), Transaction('BUY', 300, 'CHF'), Transaction('SELL', 800, 'CZK'), Transaction('SELL', 100, 'CZK'), Transaction('SELL', 400, 'EUR'), Transaction('BUY', 1000, 'EUR'), Transaction('BUY', 200, 'CZK'), Transaction('BUY', 600, 'USD'), Transaction('BUY', 400, 'EUR'), Transaction('BUY', 600, 'EUR'), Transaction('BUY', 1000, 'CZK'), Transaction('SELL', 600, 'GBP'), Transaction('BUY', 200, 'CZK'), Transaction('SELL', 1000, 'GBP'), Transaction('BUY', 100, 'CZK'), Transaction('BUY', 600, 'GBP'), Transaction('SELL', 200, 'EUR'), Transaction('BUY', 600, 'CZK'), Transaction('SELL', 800, 'USD'), Transaction('BUY', 200, 'CZK'), Transaction('BUY', 300, 'EUR'), Transaction('BUY', 600, 'EUR'), Transaction('BUY', 400, 'CHF'), Transaction('BUY', 300, 'GBP'), Transaction('SELL', 200, 'GBP'), Transaction('BUY', 900, 'CHF'), Transaction('BUY', 1000, 'USD'), Transaction('BUY', 400, 'USD'), Transaction('SELL', 800, 'CHF'), Transaction('BUY', 600, 'USD'), Transaction('BUY', 900, 'CHF'), Transaction('SELL', 900, 'CHF'), Transaction('SELL', 200, 'CZK'), Transaction('BUY', 500, 'CZK'), Transaction('SELL', 200, 'USD'), Transaction('BUY', 500, 'EUR'), Transaction('SELL', 800, 'CHF'), Transaction('BUY', 700, 'USD'), Transaction('BUY', 1000, 'GBP'), Transaction('SELL', 200, 'USD'), Transaction('SELL', 900, 'CHF'), Transaction('SELL', 500, 'CHF'), Transaction('SELL', 800, 'CHF'), Transaction('BUY', 100, 'USD'), Transaction('BUY', 900, 'CHF'), Transaction('BUY', 1000, 'CHF'), Transaction('BUY', 800, 'USD'), Transaction('BUY', 1000, 'CHF'), Transaction('SELL', 200, 'CHF'), Transaction('SELL', 200, 'CZK'), Transaction('SELL', 100, 'USD'), Transaction('SELL', 900, 'CHF'), Transaction('SELL', 900, 'USD'), Transaction('BUY', 300, 'GBP'), Transaction('SELL', 200, 'CHF'), Transaction('SELL', 100, 'GBP'), Transaction('SELL', 900, 'GBP'), Transaction('SELL', 300, 'CHF'), Transaction('BUY', 700, 'CHF'), Transaction('SELL', 200, 'GBP'), Transaction('BUY', 400, 'CZK'), Transaction('BUY', 100, 'CZK'), Transaction('SELL', 900, 'GBP'), Transaction('SELL', 900, 'GBP'), Transaction('BUY', 900, 'EUR'), Transaction('SELL', 900, 'GBP'), Transaction('BUY', 200, 'CZK'), Transaction('SELL', 100, 'USD'), Transaction('SELL', 800, 'CZK'), Transaction('SELL', 500, 'USD'), Transaction('SELL', 1000, 'CHF'), Transaction('SELL', 900, 'GBP'), Transaction('BUY', 700, 'CHF'), Transaction('BUY', 700, 'USD'), Transaction('SELL', 800, 'EUR'), Transaction('BUY', 100, 'CZK'), Transaction('BUY', 400, 'CZK'), Transaction('BUY', 700, 'CHF'), Transaction('SELL', 100, 'GBP'), Transaction('BUY', 800, 'EUR'), Transaction('BUY', 500, 'CHF'), Transaction('BUY', 200, 'EUR'), Transaction('BUY', 600, 'USD'), Transaction('BUY', 100, 'CZK'), Transaction('BUY', 200, 'CHF'), Transaction('BUY', 800, 'CHF'), Transaction('BUY', 200, 'EUR'), Transaction('SELL', 1000, 'CZK'), Transaction('BUY', 200, 'GBP'), Transaction('SELL', 100, 'CZK'), Transaction('SELL', 500, 'USD'), Transaction('BUY', 800, 'USD'), Transaction('BUY', 800, 'GBP'), Transaction('BUY', 800, 'CHF'), Transaction('BUY', 900, 'EUR'), Transaction('SELL', 900, 'USD'), Transaction('BUY', 600, 'CHF'), Transaction('BUY', 600, 'EUR'), Transaction('BUY', 1000, 'GBP'), Transaction('BUY', 900, 'CZK'), Transaction('BUY', 500, 'EUR'), Transaction('BUY', 700, 'CHF'), Transaction('SELL', 600, 'USD'), Transaction('SELL', 500, 'USD'), Transaction('SELL', 100, 'EUR'), Transaction('SELL', 500, 'GBP'), Transaction('BUY', 300, 'EUR'), Transaction('BUY', 300, 'EUR'), Transaction('SELL', 600, 'CHF'), Transaction('SELL', 1000, 'CHF'), Transaction('SELL', 500, 'EUR'), Transaction('BUY', 400, 'CZK'), Transaction('SELL', 300, 'CHF'), Transaction('BUY', 900, 'GBP'), Transaction('SELL', 100, 'CZK'), Transaction('SELL', 400, 'USD'), Transaction('BUY', 600, 'CZK'), Transaction('SELL', 300, 'CZK'), Transaction('SELL', 400, 'CHF'), Transaction('SELL', 700, 'GBP'), Transaction('SELL', 1000, 'GBP'), Transaction('BUY', 300, 'CHF'), Transaction('BUY', 800, 'EUR'), Transaction('BUY', 900, 'USD'), Transaction('BUY', 100, 'EUR'), Transaction('BUY', 100, 'USD'), Transaction('BUY', 900, 'GBP'), Transaction('SELL', 1000, 'CHF'), Transaction('SELL', 500, 'CHF'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 300, 'CHF'), Transaction('SELL', 200, 'GBP'), Transaction('BUY', 300, 'GBP'), Transaction('SELL', 800, 'CHF'), Transaction('SELL', 200, 'CZK'), Transaction('BUY', 1000, 'GBP'), Transaction('BUY', 400, 'EUR'), Transaction('SELL', 700, 'GBP'), Transaction('BUY', 700, 'CZK'), Transaction('SELL', 1000, 'CZK'), Transaction('SELL', 900, 'CHF'), Transaction('BUY', 500, 'CZK'), Transaction('SELL', 400, 'USD'), Transaction('SELL', 400, 'GBP'), Transaction('SELL', 300, 'CHF'), Transaction('SELL', 400, 'EUR'), Transaction('SELL', 1000, 'CZK'), Transaction('SELL', 200, 'USD'), Transaction('SELL', 800, 'USD'), Transaction('BUY', 500, 'USD'), Transaction('BUY', 200, 'USD'), Transaction('SELL', 900, 'USD'), Transaction('SELL', 400, 'GBP'), Transaction('BUY', 200, 'CZK'), Transaction('BUY', 600, 'USD'), Transaction('SELL', 200, 'CZK'), Transaction('SELL', 100, 'CZK'), Transaction('BUY', 500, 'EUR'), Transaction('BUY', 800, 'USD'), Transaction('SELL', 600, 'EUR'), Transaction('SELL', 800, 'GBP'), Transaction('SELL', 600, 'GBP'), Transaction('SELL', 100, 'EUR'), Transaction('SELL', 1000, 'GBP'), Transaction('SELL', 700, 'GBP'), Transaction('BUY', 700, 'EUR'), Transaction('BUY', 100, 'CHF'), Transaction('BUY', 300, 'CZK'), Transaction('BUY', 900, 'GBP'), Transaction('BUY', 300, 'USD'), Transaction('BUY', 300, 'USD'), Transaction('SELL', 100, 'USD'), Transaction('SELL', 600, 'EUR'), Transaction('BUY', 400, 'EUR'), Transaction('BUY', 700, 'CZK'), Transaction('BUY', 1000, 'GBP'), Transaction('BUY', 300, 'EUR'), Transaction('SELL', 900, 'CHF'), Transaction('SELL', 700, 'USD'), Transaction('BUY', 900, 'EUR'), Transaction('BUY', 400, 'USD'), Transaction('BUY', 600, 'CHF'), Transaction('BUY', 500, 'USD'), Transaction('SELL', 300, 'GBP'), Transaction('BUY', 600, 'CHF'), Transaction('SELL', 1000, 'CZK'), Transaction('SELL', 600, 'GBP'), Transaction('BUY', 800, 'GBP'), Transaction('BUY', 400, 'CHF'), Transaction('BUY', 800, 'GBP'), Transaction('BUY', 300, 'CZK'), Transaction('SELL', 100, 'EUR'), Transaction('SELL', 600, 'CHF'), Transaction('BUY', 600, 'EUR'), Transaction('BUY', 200, 'CHF'), Transaction('BUY', 800, 'CHF'), Transaction('BUY', 300, 'CHF'), Transaction('BUY', 800, 'EUR'), Transaction('SELL', 300, 'GBP'), Transaction('SELL', 300, 'EUR'), Transaction('BUY', 600, 'GBP'), Transaction('BUY', 300, 'USD'), Transaction('SELL', 1000, 'GBP'), Transaction('BUY', 500, 'CZK'), Transaction('BUY', 100, 'USD'), Transaction('SELL', 500, 'EUR'), Transaction('SELL', 100, 'CZK'), Transaction('SELL', 600, 'EUR'), Transaction('SELL', 700, 'GBP'), Transaction('SELL', 600, 'CHF'), Transaction('BUY', 600, 'USD'), Transaction('BUY', 200, 'CZK'), Transaction('BUY', 500, 'CHF'), Transaction('SELL', 300, 'USD'), Transaction('BUY', 400, 'CHF'), Transaction('SELL', 600, 'EUR'), Transaction('SELL', 800, 'CHF'), Transaction('SELL', 400, 'CHF'), Transaction('SELL', 400, 'USD'), Transaction('SELL', 400, 'EUR'), Transaction('BUY', 500, 'EUR'), Transaction('SELL', 100, 'CZK'), Transaction('SELL', 500, 'CHF'), Transaction('BUY', 800, 'EUR'), Transaction('SELL', 500, 'CZK'), Transaction('SELL', 600, 'EUR'), Transaction('SELL', 700, 'GBP'), Transaction('BUY', 200, 'CZK'), Transaction('SELL', 900, 'CHF'), Transaction('SELL', 1000, 'CZK'), Transaction('SELL', 1000, 'CHF'), Transaction('BUY', 300, 'CZK'), Transaction('BUY', 400, 'USD'), Transaction('BUY', 400, 'CHF'), Transaction('SELL', 300, 'CHF'), Transaction('SELL', 700, 'EUR'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 200, 'CHF'), Transaction('BUY', 800, 'EUR'), Transaction('BUY', 500, 'GBP'), Transaction('BUY', 100, 'CZK'), Transaction('BUY', 700, 'GBP'), Transaction('SELL', 100, 'EUR'), Transaction('BUY', 100, 'CZK'), Transaction('SELL', 400, 'GBP'), Transaction('BUY', 800, 'USD'), Transaction('BUY', 500, 'USD'), Transaction('BUY', 700, 'CHF'), Transaction('BUY', 600, 'CZK'), Transaction('SELL', 800, 'EUR'), Transaction('SELL', 1000, 'GBP'), Transaction('SELL', 900, 'GBP'), Transaction('SELL', 200, 'CHF'), Transaction('SELL', 800, 'GBP'), Transaction('BUY', 700, 'CHF'), Transaction('BUY', 400, 'EUR'), Transaction('BUY', 300, 'CHF'), Transaction('SELL', 600, 'USD'), Transaction('BUY', 900, 'USD'), Transaction('BUY', 500, 'CZK'), Transaction('BUY', 500, 'USD'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 300, 'CZK'), Transaction('SELL', 700, 'CZK'), Transaction('SELL', 900, 'GBP'), Transaction('SELL', 200, 'USD'), Transaction('BUY', 600, 'EUR'), Transaction('BUY', 600, 'EUR'), Transaction('SELL', 500, 'USD'), Transaction('BUY', 800, 'CHF'), Transaction('BUY', 700, 'GBP'), Transaction('SELL', 400, 'GBP'), Transaction('BUY', 1000, 'CHF'), Transaction('SELL', 600, 'USD'), Transaction('SELL', 200, 'CHF'), Transaction('SELL', 300, 'GBP'), Transaction('BUY', 400, 'EUR'), Transaction('SELL', 100, 'CHF'), Transaction('SELL', 500, 'GBP'), Transaction('BUY', 600, 'GBP'), Transaction('SELL', 500, 'GBP'), Transaction('SELL', 1000, 'USD'), Transaction('SELL', 1000, 'GBP'), Transaction('SELL', 300, 'GBP'), Transaction('BUY', 900, 'CZK'), Transaction('BUY', 100, 'CZK'), Transaction('BUY', 100, 'CHF'), Transaction('SELL', 700, 'CHF'), Transaction('BUY', 600, 'CHF'), Transaction('BUY', 100, 'CHF'), Transaction('BUY', 700, 'CZK'), Transaction('BUY', 600, 'CZK'), Transaction('BUY', 500, 'CHF'), Transaction('SELL', 700, 'GBP'), Transaction('SELL', 300, 'GBP'), Transaction('SELL', 700, 'USD'), Transaction('BUY', 300, 'EUR'), Transaction('BUY', 600, 'CZK'), Transaction('SELL', 500, 'USD'), Transaction('BUY', 900, 'EUR'), Transaction('SELL', 400, 'GBP'), Transaction('SELL', 800, 'CHF'), Transaction('BUY', 400, 'GBP'), Transaction('SELL', 400, 'CHF'), Transaction('BUY', 300, 'USD'), Transaction('BUY', 1000, 'CZK'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 500, 'USD'), Transaction('SELL', 1000, 'CZK'), Transaction('SELL', 100, 'USD'), Transaction('SELL', 900, 'CZK'), Transaction('SELL', 200, 'GBP'), Transaction('SELL', 600, 'EUR'), Transaction('BUY', 600, 'CHF'), Transaction('BUY', 200, 'CHF'), Transaction('BUY', 800, 'USD'), Transaction('SELL', 100, 'USD'), Transaction('SELL', 200, 'USD'), Transaction('SELL', 900, 'GBP'), Transaction('SELL', 1000, 'CHF'), Transaction('BUY', 100, 'CZK'), Transaction('SELL', 800, 'EUR'), Transaction('BUY', 800, 'GBP'), Transaction('BUY', 1000, 'GBP'), Transaction('SELL', 100, 'CHF'), Transaction('BUY', 900, 'CHF'), Transaction('BUY', 100, 'CHF'), Transaction('BUY', 700, 'USD'), Transaction('BUY', 400, 'USD'), Transaction('SELL', 600, 'CHF'), Transaction('SELL', 300, 'USD'), Transaction('SELL', 500, 'EUR'), Transaction('SELL', 700, 'EUR'), Transaction('BUY', 300, 'CZK'), Transaction('SELL', 1000, 'GBP'), Transaction('BUY', 300, 'GBP'), Transaction('SELL', 200, 'CHF'), Transaction('SELL', 700, 'CHF'), Transaction('BUY', 200, 'CZK'), Transaction('BUY', 900, 'GBP'), Transaction('SELL', 600, 'CZK'), Transaction('SELL', 700, 'EUR'), Transaction('SELL', 700, 'USD'), Transaction('BUY', 300, 'EUR'), Transaction('BUY', 900, 'USD'), Transaction('BUY', 800, 'USD'), Transaction('SELL', 1000, 'CZK'), Transaction('SELL', 200, 'GBP'), Transaction('BUY', 200, 'EUR'), Transaction('SELL', 1000, 'GBP'), Transaction('BUY', 300, 'USD'), Transaction('SELL', 500, 'USD'), Transaction('BUY', 1000, 'GBP'), Transaction('SELL', 800, 'USD'), Transaction('SELL', 900, 'CHF'), Transaction('SELL', 400, 'CHF'), Transaction('BUY', 400, 'EUR'), Transaction('SELL', 500, 'EUR'), Transaction('BUY', 200, 'CHF'), Transaction('BUY', 200, 'GBP'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 500, 'CZK'), Transaction('BUY', 600, 'GBP'), Transaction('BUY', 1000, 'USD'), Transaction('BUY', 500, 'EUR'), Transaction('SELL', 300, 'USD'), Transaction('SELL', 800, 'GBP'), Transaction('BUY', 300, 'CZK'), Transaction('BUY', 100, 'CZK'), Transaction('BUY', 1000, 'CHF'), Transaction('SELL', 400, 'USD'), Transaction('SELL', 400, 'CHF'), Transaction('BUY', 1000, 'CHF'), Transaction('SELL', 200, 'EUR'), Transaction('BUY', 400, 'EUR'), Transaction('BUY', 700, 'CHF'), Transaction('SELL', 700, 'USD'), Transaction('BUY', 500, 'GBP'), Transaction('BUY', 1000, 'EUR'), Transaction('BUY', 700, 'CHF'), Transaction('BUY', 600, 'EUR'), Transaction('BUY', 800, 'USD'), Transaction('BUY', 800, 'EUR'), Transaction('SELL', 900, 'EUR'), Transaction('SELL', 200, 'USD'), Transaction('BUY', 500, 'USD'), Transaction('SELL', 100, 'GBP'), Transaction('SELL', 900, 'CZK'), Transaction('SELL', 900, 'EUR'), Transaction('BUY', 600, 'CZK'), Transaction('BUY', 300, 'CZK'), Transaction('SELL', 100, 'USD'), Transaction('BUY', 800, 'GBP'), Transaction('BUY', 1000, 'GBP'), Transaction('SELL', 800, 'CHF'), Transaction('BUY', 700, 'USD'), Transaction('SELL', 1000, 'GBP'), Transaction('SELL', 900, 'CHF'), Transaction('SELL', 400, 'CZK'), Transaction('BUY', 1000, 'EUR'), Transaction('BUY', 700, 'EUR'), Transaction('SELL', 400, 'USD'), Transaction('SELL', 200, 'CZK'), Transaction('BUY', 500, 'CZK'), Transaction('SELL', 600, 'USD'), Transaction('SELL', 600, 'USD'), Transaction('BUY', 700, 'GBP'), Transaction('SELL', 900, 'CZK'), Transaction('SELL', 100, 'USD'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 400, 'CHF'), Transaction('BUY', 500, 'GBP'), Transaction('SELL', 200, 'USD'), Transaction('BUY', 700, 'USD'), Transaction('BUY', 600, 'CHF'), Transaction('BUY', 200, 'GBP'), Transaction('SELL', 600, 'CZK'), Transaction('BUY', 200, 'CHF'), Transaction('BUY', 400, 'CZK'), Transaction('SELL', 300, 'USD'), Transaction('SELL', 1000, 'GBP'), Transaction('BUY', 500, 'CZK'), Transaction('BUY', 200, 'CHF'), Transaction('SELL', 900, 'CHF'), Transaction('BUY', 900, 'USD'), Transaction('SELL', 700, 'GBP'), Transaction('SELL', 1000, 'CHF'), Transaction('SELL', 600, 'USD'), Transaction('SELL', 300, 'CHF'), Transaction('BUY', 100, 'EUR'), Transaction('BUY', 500, 'CHF'), Transaction('SELL', 300, 'GBP'), Transaction('SELL', 1000, 'CHF'), Transaction('SELL', 100, 'USD'), Transaction('SELL', 400, 'USD'), Transaction('BUY', 500, 'GBP'), Transaction('BUY', 300, 'GBP'), Transaction('SELL', 700, 'GBP'), Transaction('BUY', 400, 'EUR'), Transaction('SELL', 100, 'GBP'), Transaction('BUY', 700, 'CHF'), Transaction('SELL', 900, 'EUR'), Transaction('BUY', 1000, 'EUR'), Transaction('BUY', 200, 'EUR'), Transaction('BUY', 700, 'EUR'), Transaction('BUY', 100, 'CZK'), Transaction('SELL', 900, 'CZK'), Transaction('SELL', 300, 'GBP'), Transaction('SELL', 1000, 'GBP'), Transaction('BUY', 900, 'CHF'), Transaction('BUY', 400, 'CHF'), Transaction('BUY', 700, 'CHF'), Transaction('BUY', 500, 'CHF'), Transaction('SELL', 200, 'EUR'), Transaction('BUY', 500, 'EUR'), Transaction('SELL', 600, 'EUR'), Transaction('SELL', 400, 'CZK'), Transaction('SELL', 200, 'EUR'), Transaction('BUY', 700, 'CHF'), Transaction('BUY', 1000, 'CHF'), Transaction('SELL', 700, 'EUR'), Transaction('BUY', 900, 'EUR'), Transaction('BUY', 700, 'CHF'), Transaction('SELL', 900, 'GBP'), Transaction('BUY', 100, 'USD'), Transaction('BUY', 500, 'CHF'), Transaction('SELL', 200, 'GBP'), Transaction('SELL', 300, 'EUR'), Transaction('BUY', 200, 'CHF'), Transaction('BUY', 800, 'USD'), Transaction('SELL', 600, 'EUR'), Transaction('SELL', 500, 'EUR'), Transaction('SELL', 400, 'CHF'), Transaction('SELL', 1000, 'CHF'), Transaction('SELL', 200, 'EUR'), Transaction('BUY', 800, 'EUR'), Transaction('BUY', 500, 'CZK'), Transaction('BUY', 400, 'GBP'), Transaction('BUY', 900, 'GBP'), Transaction('BUY', 900, 'GBP'), Transaction('SELL', 500, 'CZK'), Transaction('BUY', 900, 'CHF'), Transaction('BUY', 100, 'CZK'), Transaction('BUY', 400, 'USD'), Transaction('BUY', 100, 'USD'), Transaction('SELL', 700, 'GBP'), Transaction('BUY', 800, 'EUR'), Transaction('BUY', 300, 'CHF'), Transaction('BUY', 500, 'USD'), Transaction('BUY', 900, 'CHF'), Transaction('BUY', 500, 'GBP'), Transaction('SELL', 600, 'CHF'), Transaction('SELL', 600, 'CZK'), Transaction('SELL', 100, 'USD'), Transaction('BUY', 200, 'GBP'), Transaction('BUY', 900, 'GBP')]

# %% [markdown]
# ### Sprawdź swoje rozwiązanie wykonując kod poniżej

# %%
# Weryfikacja poprawności rozwiązania
money_exchange = MoneyExchange(price_table, CashRegister(cash_register_data))
for idx, transaction in enumerate(transactions):
    print(f'Trying to make transaction #{idx} ({transaction})')
    money_exchange.make_transaction(transaction)
    print(f'############################')
money_exchange.print_report()
# Out:
# Trying to make transaction #0 (Transaction('BUY', 300, 'GBP'))
# Transaction possible. Processing.
# Deposit 300 GBP to cash register
# Withdraw 1478.1899999999998 PLN from cash register
# ############################
# Trying to make transaction #1 (Transaction('BUY', 800, 'GBP'))
# Transaction possible. Processing.
# Deposit 800 GBP to cash register
# Withdraw 3941.8399999999997 PLN from cash register
# ############################
# Trying to make transaction #2 (Transaction('BUY', 200, 'CZK'))
# Transaction possible. Processing.
# Deposit 200 CZK to cash register
# Withdraw 33.239999999999995 PLN from cash register
# ############################
# Trying to make transaction #3 (Transaction('SELL', 200, 'USD'))
# Transaction possible. Processing.
# Deposit 790.68 PLN to cash register
# Withdraw 200 USD from cash register
# ############################
# Trying to make transaction #4 (Transaction('BUY', 800, 'USD'))
# Transaction possible. Processing.
# ...

# %% [markdown]
# # 3. Zadanie z serii prostych i sympatycznych (200 pkt.)
# Korzystając z wyrażeń regularnych, wyświetl za pomocą funkcji `print()` **wyłącznie dozwolone znaki** z poniższego tekstu. Dozwolonymi znakami są:
# * znaki specjalne (uwaga na znaki, które mają dodatkowe funkcje w bibliotece re :) )
# * litera T
# * wszystkie białe znaki

# %%
txt = '''
 B6mz9  I 
  aw +U--rRwPmG-Xy3VUQsJ-w-5-w-hw-ad235--I----A+ALc  b F rjXbYa5DkZJa
 iq0 mOfzrjGj5J8 85|.1-8--0---Y4E-8-ysw-FF---w9XU.|Qj pj  B blFxCpkHa
x mQoK qp uM|rby|gR   zFVpi rEi8 SQ6 x WQ xBqy   d vj1|2|J 1Ma  cC L,uQx_   6x  _uu5FPjlhJzDh
Zq5kZ  O D|UUZj|DgRp     APSr AVKAS  0   JCi05 ||kP  kXHll d E 5A8Z|Z6\oDv7_,Ie-K~/swxBd8i0iY
Fg7Hj0 u  XFAQ|9|4  F  C ZGhH   E   UY U||FdoqFfhaFym Y0P8t  4ZM PLL /U97 _ 2V B_ rId0|   CBI5 ,0--.s36vM7v4hRdwSOXwFe3e
vE   Hd4|wfZKL|ojlRdZ  2 1 y73 yPg9Jr x8 f2a UMCiwMz Q   izIs|tyjKItK| P G pEM Y(0r6  @E VF @ )O  IBV f/ ,-623R60EIaf
5DX   f|JCdZArl2L+C6pb-P-LG--45-a---Q3-x-zVQOL1-u-P+Vg|Sp  9Ss 94rb9 ER \L  _TjBox_y9/3o6-.m_(B v(MLKduy7ezO1oo
GE W ot2l7 +XhaZ-ZB.Gjey3zD8VPco.zR---MPA9---O0C-3lB-..-f7+Pj 5 S UuFaYe E /  EGC f2 f J  y tR 2LF`.6 aK\MuUJS57rc
M CGB  .oh--pqr38Q-yEDJkujez--l---hHJbzQ8Lae8UVm----gMLO--.W FfCXh  5ihIdKwS 0| 114l  4 I5   EL2  _G C \ Pu|ov07Gou67
 jM y/y BHpLwb/=B5KEl=tLoL==Z=FKOxf====C=p==xmd\ Cjd\ga  1 D \zJ xhSFd\8 ,yEYa 3zUWq /8b hFP giQl  lM7  z|ufm1uIrtwJg
y1Z3 /g pm/hE==D==rdtI5===F=9xxbStg=fKp==Og=g=oG=j\\7 \\1    sewcq|MxKLZeF|D 9B55|-0l_eL\Mq_RlVy_Pd   d/QWUVL1vjSvim
J/____O_R_2_xiczvhX6rH9_wFM2Qi_DFc__KHf___olfC___h__u_zh\  (M(4_/F4`(W__VY_Zr_AXSwWl,w7dJXFG-zJkoFYYSMi6FUg2
\\7__V_9z_O___8L0_s7Y_R8A1p___d3PD8U__X_aCR5_w8d_G_Wf__m/9ls9cKUpU5'''

# %%
import re

#wzorzec
allowed_pattern = r'[T \s\t\r\n!@#$%^&*()_+\-={}\[\]:;"\'<>,.?/|\\]'

result = re.findall(allowed_pattern, txt)
allowed_characters = ''.join(result)
print(allowed_characters)
# Out:
#
#    +--------------+
#    |.------------.|
#    ||            ||    ,_     _
#    ||            ||     |\_,-/
#    ||            ||     / _  _ |    ,--.
#    ||            ||    (  @  @ )   / ,-
#    |+------------+|     \  _T_/-._( (
#    +-..--------..-+     /         . \
#    .--------------.    |         _  \ |
#   / /============\ \    \ \ ,  /      |
#  / /==============\ \    || |-_\__   /
# /____________________\  ((_/(____,-
# \____________________/

# %% [markdown]
# # 4. Czytanie plików, wyciąganie z nich informacji (400 pkt.)
#
# Zadanie polega na wyciągnięciu `id klientów` z plików i zapisaniu ich do słownika. Kluczami w słowniku powinny być nazwy plików, a wartościami id klientów wyciągnięte z danego pliku. Jeżeli plik zawiera kilka id klientów, zapisz je w liście.
#
# ## Jak rozpoznać poprawne id klienta?
# Id klienta:
# - ma długość 10 znaków
# - składa się z samych cyfr
# - suma cyfr wynosi 50
#
# ## Dane wejściowe
# Pliki do analizy znajdują się w katalogu `docs_hfwc#5`. Powodzenia!

# %%
import pprint
import os
import csv

def is_valid_client_id(client_id):
    # Sprawdzenie czy ID klienta ma długość 10 znaków, składa się z samych cyfr i suma cyfr wynosi 50.
    if len(client_id) != 10 or not client_id.isdigit() or sum(map(int, client_id)) != 50:
        return False
    return True

def extract_client_ids_from_file(file_path):
    client_ids = []
    with open(file_path, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            for data in row:
                if is_valid_client_id(data):
                    client_ids.append(data)
    return client_ids

def main():
    folder_path = 'C:\\Users\\sstol\\OneDrive\\Dokumenty\\kodowanie-BlackMonster\\Python\\hfwc5\\docs_hfwc#5'
    files = os.listdir(folder_path)
    client_ids_dict = {}

    for file_name in files:
        file_path = os.path.join(folder_path, file_name)
        client_ids = extract_client_ids_from_file(file_path)
        if client_ids:
            client_ids_dict[file_name] = client_ids

    pprint.pprint(client_ids_dict)

if __name__ == "__main__":
    main()
# Out:
# {'0ft1iosx.csv': ['8081288519',
#                   '6630847358',
#                   '8408154578',
#                   '3743147489',
#                   '8616408287',
#                   '7774656314',
#                   '9563069174',
#                   '1471973729',
#                   '9158586440',
#                   '6734824277',
#                   '4805815379',
#                   '9804737507',
#                   '4334086976',
#                   '1943942963',
#                   '8243559428',
#                   '3167735648',
#                   '8772541754',
#                   '2346975554',
#                   '4890143696',
#                   '8082295619',
#                   '9497198120',
#                   '4336535966',
#                   '3645551687',
#                   '6588745205',
#                   '1377470777',
#                   '9623380748',
#                   '0487182857',
#                   '0817885436',
#                   '0261966488',
# ...

# %% [markdown]
# # 5. Import danych do bazy (200 pkt.)

# %% [markdown]
# W pliku `database.sqlite3` znajduje się baza danych na której należy wykonać to zadanie.
#
# **Nie wolno skasować danych, które istnieją w bazie!**

# %% [markdown]
# ## Import klientów
# Mając listę klientów zaimportuj ich do bazy danych (tabela customers).
# Zwróć uwagę, że klienci zapisani są na liście jako 'Imie Nazwisko' a w bazie danych na imię i nazwisko są osobne pola. **Aby przypisać id, użyj autoincrement.**
#
# ### Przykładowe zapytanie
# `insert into customers(first_name, last_name) values('Bartosz', 'Głowacki')`

# %%
customers = ['Bartosz Głowacki', 'Eryk Kamiński', 'Igor Witkowski', 'Olga Szulc', 'Igor Nowak',
             'Mikołaj Wasilewski', 'Bogna Stępień', 'Piotr Błaszczyk', 'Małgorzata Wróblewska', 'Bogumił Kaczmarczyk',
             'Heronim Marciniak', 'Denis Kowalski', 'Judyta Kaczmarczyk', 'Bartłomiej Nowak', 'Daniela Pietrzak',
             'Magda Wójcik', 'Edward Jasiński', 'Adrian Szymczak', 'Elwira Malinowska', 'Małgorzata Makowska',
             'Mateusz Mazur', 'Dominika Lis', 'Izabela Witkowska', 'Kewin Kowalczyk', 'Józefa Chmielewska',
             'Bernadetta Sadowska', 'Aureliusz Nowak', 'Florentyna Górska', 'Adela Kołodziej', 'Alice Mazur',
             'Angelika Duda', 'Julita Górecka', 'Marcelina Duda', 'Alexander Kowalski', 'Filip Brzeziński',
             'Paula Zakrzewska', 'Alfred Makowski', 'Alice Błaszczyk', 'Dominika Adamska', 'Aureliusz Pietrzak',
             'Damian Kozłowski', 'Dorian Andrzejewski', 'Irena Stępień', 'Ernest Nowak', 'Adriana Kowalska',
             'Jowita Kalinowska', 'Asia Dąbrowska', 'Matylda Marciniak', 'Gabriela Szewczyk', 'Julia Szewczyk',
             'Pamela Michalak', 'Stanisława Czarnecka', 'Aleksy Przybylski', 'Bartosz Rutkowski', 'Olaf Szymański',
             'Lila Jankowska', 'Alisa Sikorska', 'Mikołaj Nowak', 'Stanisława Sawicka', 'Judyta Wojciechowska',
             'Balbina Sikorska', 'Barbara Urbańska', 'Bernadetta Urbańska', 'Alojzy Zalewski', 'Julian Kowalczyk',
             'Gabriel Nowak', 'Lucyna Sikorska', 'Błażej Ostrowski', 'Alisa Lewandowska', 'Leszek Nowak',
             'Dariusz Szymczak', 'Jadwiga Szulc', 'Paula Szymczak', 'Kryspin Szymański', 'Ignacy Kaźmierczak',
             'Norbert Jasiński', 'Bogumił Stępień', 'Andrea Szulc', 'Roman Baranowski', 'Marcin Duda',
             'Irena Wasilewska', 'Julian Baranowski', 'Lara Nowak', 'Anatol Sawicki', 'Dariusz Zawadzki',
             'Lucyna Chmielewska', 'Konstanty Zalewski', 'Paulina Kaczmarczyk', 'Ireneusz Zieliński', 'Asia Nowak',
             'Maksymilian Szewczyk', 'Jola Urbańska', 'Denis Zieliński', 'Maciej Głowacki', 'Alex Włodarczyk',
             'Gniewomir Laskowski', 'Leonardo Sikorski', 'Amanda Szczepańska', 'Honorata Sokołowska',
             'Albert Piotrowski']

# %%
import sqlite3

def import_customers(customers):
    try:
        conn = sqlite3.connect('database.sqlite3')
        cursor = conn.cursor()

        # Przeiteruj przez listę klientów i wstaw ich do tabeli customers
        for customer in customers:
            first_name, last_name = customer.split(' ', 1)  # Podziel imię i nazwisko
            cursor.execute('INSERT INTO customers (first_name, last_name) VALUES (?, ?)', (first_name, last_name))

        conn.commit()
        print("Klienci zostali zaimportowani do bazy danych!")

    except sqlite3.Error as e:
        print("Wystąpił błąd podczas importu klientów:", e)

    finally:
        if conn:
            conn.close()

# Wywołanie funkcji do importu klientów
import_customers(customers)
# Out:
# Klienci zostali zaimportowani do bazy danych!

# %%
import sqlite3

with sqlite3.connect('database.sqlite3') as connection:
    cursor = connection.cursor()
    results = cursor.execute('select * from customers')
    result = results.fetchone()
    while result:
        print(result)
        result = results.fetchone()
# Out:
# (10000, 'Adam', 'Nowacki')
# (10001, 'Jan', 'Kowalski')
# (10002, 'Bartosz', 'Głowacki')
# (10003, 'Eryk', 'Kamiński')
# (10004, 'Igor', 'Witkowski')
# (10005, 'Olga', 'Szulc')
# (10006, 'Igor', 'Nowak')
# (10007, 'Mikołaj', 'Wasilewski')
# (10008, 'Bogna', 'Stępień')
# (10009, 'Piotr', 'Błaszczyk')
# (10010, 'Małgorzata', 'Wróblewska')
# (10011, 'Bogumił', 'Kaczmarczyk')
# (10012, 'Heronim', 'Marciniak')
# (10013, 'Denis', 'Kowalski')
# (10014, 'Judyta', 'Kaczmarczyk')
# (10015, 'Bartłomiej', 'Nowak')
# (10016, 'Daniela', 'Pietrzak')
# (10017, 'Magda', 'Wójcik')
# (10018, 'Edward', 'Jasiński')
# (10019, 'Adrian', 'Szymczak')
# (10020, 'Elwira', 'Malinowska')
# (10021, 'Małgorzata', 'Makowska')
# (10022, 'Mateusz', 'Mazur')
# (10023, 'Dominika', 'Lis')
# (10024, 'Izabela', 'Witkowska')
# (10025, 'Kewin', 'Kowalczyk')
# (10026, 'Józefa', 'Chmielewska')
# (10027, 'Bernadetta', 'Sadowska')
# (10028, 'Aureliusz', 'Nowak')
# (10029, 'Florentyna', 'Górska')
# (10030, 'Adela', 'Kołodziej')
# ...

# %% [markdown]
# ## Import kont
# W bazie znajduje się tabela accounts. Ta tabela ma klucz obcy (pole owner), który powinien wskazywać na konkretnego klienta (**relacja customers.id = accounts.owner**).
#
# Zapisz konta z listy w bazie w taki sposób, aby właścicielami kolejnych kont, byli kolejni klienci z poprzedniej listy (relacja powinna być zachowana).
#
# ## Przykład
# Bartosz Głowacki jest włacicielem konta PL42222941176247135539240187
# Eryk Kamiński jest włacicielem konta PL81786645034401957047621964

# %%
accounts = ['PL42222941176247135539240187', 'PL81786645034401957047621964', 'PL61827884040081351674977449',
                'PL70724511734909169446820569', 'PL84088258283620570843192707', 'PL20452518470134792225378787',
                'PL11462380436218108192209769', 'PL95767827625047808090917558', 'PL23904771660065411425795304',
                'PL50456201958822830819035014', 'PL90060634522008222843557969', 'PL09129845100611575983827969',
                'PL04933075786409877858276361', 'PL41216396206003046331355076', 'PL76219217364176207985297587',
                'PL68993998198602899323173401', 'PL88830777665031601783143189', 'PL65340480182486847430048663',
                'PL68863632433343392423227897', 'PL79704373844446106714615582', 'PL62124047339933926409512840',
                'PL59936308346070342340713270', 'PL01814461794647716676795119', 'PL14102243867783388006523077',
                'PL24392138257182734234089178', 'PL77676884634180964236248552', 'PL01470396332978558099677065',
                'PL19347977707644163737014764', 'PL10681175466306981734162786', 'PL59600358209202979627730631',
                'PL26886489427644002141973035', 'PL41837024301475584382636046', 'PL11807421031730166977901943',
                'PL31375493106710264805821471', 'PL30121680781564585445085558', 'PL29089171293201401336352578',
                'PL23603149704722199369074172', 'PL95616902387609198239915671', 'PL57900545121373375343184959',
                'PL60136490531189749493055978', 'PL51225145357812942212550821', 'PL77852127455365152554745119',
                'PL39991628478868227758642973', 'PL76900952112809978771182959', 'PL65522770617561503650617973',
                'PL18357348816848270635281232', 'PL40586063776344068055216527', 'PL21414676378766426692444943',
                'PL93629760991267126626993372', 'PL46768173084845201589752230', 'PL20556928680243176079149641',
                'PL58260331599237416760457737', 'PL31064108414981300794013926', 'PL01356345801318307683568375',
                'PL33051273184191483207656357', 'PL80938217545535385101851725', 'PL84732367737813888530438170',
                'PL19215655957894008729243313', 'PL33076090051556570674071668', 'PL62539178393034479371408649',
                'PL48908177812717582662144004', 'PL06404640603082015911868457', 'PL96116152184234638165207202',
                'PL49574635285322129141468444', 'PL19743931648026435948339706', 'PL69582511090579023733802588',
                'PL82585793687620401129209166', 'PL94019190105333137692760549', 'PL33821675745593905060856093',
                'PL02338058107271655327334708', 'PL76166179754375889266152754', 'PL26198437171737832118498390',
                'PL95502403681241108754729090', 'PL58428109397734769179294471', 'PL21799815390434193920237672',
                'PL51797657669605689620730990', 'PL96586930090652429816689728', 'PL06382220739350141398924713',
                'PL33181228649464900697716934', 'PL89941988116669068813398429', 'PL73334232772825512182008550',
                'PL82916461214174037398335873', 'PL18691754021197599965492442', 'PL82673813626128341820209884',
                'PL92423876370750359655316762', 'PL60749924159117402538720566', 'PL37189594313417678231066556',
                'PL70123091297399721029963702', 'PL58490631164114600858764664', 'PL13865510264267291860056886',
                'PL06469479024555138009439323', 'PL92850233950586676619619528', 'PL85020894599908210318621287',
                'PL19472884962405642320767244', 'PL68053747830206845836539399', 'PL33240034460942914479938225',
                'PL88089860327088708721744408', 'PL39112899454816845930799230', 'PL16750298033250446608408495',
                'PL85353962531367181549425970']

# %%
import sqlite3

def check_if_account_number_exists(conn, account_number):
    cursor = conn.cursor()
    cursor.execute("SELECT COUNT(*) FROM accounts WHERE number = ?", (account_number,))
    count = cursor.fetchone()[0]
    return count > 0

def add_account_with_incremented_id(accounts):
    conn = sqlite3.connect('database.sqlite3')

    # Pobieramy najwyższe id obecnie istniejące w tabeli accounts
    cursor = conn.cursor()
    cursor.execute("SELECT MAX(id) FROM accounts")
    max_id = cursor.fetchone()[0]

    # Dodajemy nowe rekordy dla każdego numeru konta z listy accounts
    for account_number in accounts:
        # Sprawdzamy, czy numer konta już istnieje w tabeli
        if not check_if_account_number_exists(conn, account_number):
            # Zwiększamy id i owner o 1 i 9000 dla każdego kolejnego rekordu
            new_id = max_id + 1
            new_owner = new_id + 9000

            # Wstawiamy nowy rekord do tabeli accounts
            cursor.execute("INSERT INTO accounts (id, number, owner) VALUES (?, ?, ?)", (new_id, account_number, new_owner))

            # Aktualizujemy wartość max_id dla następnego rekordu
            max_id = new_id

    conn.commit()
    conn.close()

# Dodajemy nowe rekordy do tabeli accounts z odpowiednimi id i owner
add_account_with_incremented_id(accounts)

# %%
#sprawdzenie stanu bazy
import sqlite3

with sqlite3.connect('database.sqlite3') as connection:
    cursor = connection.cursor()
    results = cursor.execute('select * from accounts')
    print("\nNazwy pól w bazie")
    for field_description in cursor.description:
        print(field_description[0])
        
with sqlite3.connect('database.sqlite3') as connection:
    cursor = connection.cursor()
    results = cursor.execute('select * from accounts')
    result = results.fetchone()
    while result:
        print(result)
        result = results.fetchone()
# Out:
# Nazwy pól w bazie
# id
# number
# owner
# (1000, 'PL42222941176247135539240187', 10000)
# (1001, 'PL81786645034401957047621964', 10001)
# (1002, 'PL61827884040081351674977449', 10002)
# (1003, 'PL70724511734909169446820569', 10003)
# (1004, 'PL84088258283620570843192707', 10004)
# (1005, 'PL20452518470134792225378787', 10005)
# (1006, 'PL11462380436218108192209769', 10006)
# (1007, 'PL95767827625047808090917558', 10007)
# (1008, 'PL23904771660065411425795304', 10008)
# (1009, 'PL50456201958822830819035014', 10009)
# (1010, 'PL90060634522008222843557969', 10010)
# (1011, 'PL09129845100611575983827969', 10011)
# (1012, 'PL04933075786409877858276361', 10012)
# (1013, 'PL41216396206003046331355076', 10013)
# (1014, 'PL76219217364176207985297587', 10014)
# (1015, 'PL68993998198602899323173401', 10015)
# (1016, 'PL88830777665031601783143189', 10016)
# (1017, 'PL65340480182486847430048663', 10017)
# (1018, 'PL68863632433343392423227897', 10018)
# ...

# %%
#Wyprintowanie zgodnie z przykładem w zadaniu
import sqlite3

def print_customer_accounts_info():
    conn = sqlite3.connect('database.sqlite3')
    cursor = conn.cursor()

    # Wykonujemy zapytanie SQL, które połączy tabelę customers z tabelą accounts na podstawie relacji customers.id = accounts.owner
    cursor.execute("SELECT c.first_name, c.last_name, a.number "
                   "FROM customers c "
                   "JOIN accounts a ON c.id = a.owner")

    # Pobieramy wyniki zapytania
    rows = cursor.fetchall()

    # Wyświetlamy informacje o każdym wyniku zapytania
    for row in rows:
        first_name, last_name, account_number = row
        print(f"{first_name} {last_name} jest właścicielem konta {account_number}")

    conn.close()

# Wykonujemy zapytanie i wyświetlamy informacje o klientach i numerach ich kont
print_customer_accounts_info()
# Out:
# Adam Nowacki jest właścicielem konta PL42222941176247135539240187
# Jan Kowalski jest właścicielem konta PL81786645034401957047621964
# Bartosz Głowacki jest właścicielem konta PL61827884040081351674977449
# Eryk Kamiński jest właścicielem konta PL70724511734909169446820569
# Igor Witkowski jest właścicielem konta PL84088258283620570843192707
# Olga Szulc jest właścicielem konta PL20452518470134792225378787
# Igor Nowak jest właścicielem konta PL11462380436218108192209769
# Mikołaj Wasilewski jest właścicielem konta PL95767827625047808090917558
# Bogna Stępień jest właścicielem konta PL23904771660065411425795304
# Piotr Błaszczyk jest właścicielem konta PL50456201958822830819035014
# Małgorzata Wróblewska jest właścicielem konta PL90060634522008222843557969
# Bogumił Kaczmarczyk jest właścicielem konta PL09129845100611575983827969
# Heronim Marciniak jest właścicielem konta PL04933075786409877858276361
# Denis Kowalski jest właścicielem konta PL41216396206003046331355076
# ...

# %% [markdown]
# ## Wykonanie zapytania
# Wykonaj zapytanie, które zwróci numery kont osób o nazwisku 'Nowak'. Użyj relacji między tabelami customers i accounts.

# %%
import sqlite3
import pprint

def get_accounts_by_last_name(last_name):
    conn = sqlite3.connect('database.sqlite3')
    cursor = conn.cursor()

    # Wykonujemy zapytanie SQL, które połączy tabelę customers z tabelą accounts na podstawie relacji customers.id = accounts.owner
    # i zwróci numery kont osób o podanym nazwisku
    cursor.execute("SELECT a.number "
                   "FROM customers c "
                   "JOIN accounts a ON c.id = a.owner "
                   "WHERE c.last_name = ?", (last_name,))

    # Pobieramy wyniki zapytania
    rows = cursor.fetchall()

    # Zamykamy połączenie
    conn.close()

    # Zwracamy listę numerów kont
    return [row[0] for row in rows]

# Wykonujemy zapytanie i zwracamy numery kont osób o nazwisku 'Nowak'
last_name = 'Nowak'
nowak_accounts = get_accounts_by_last_name(last_name)
pprint.pprint(nowak_accounts)
# Out:
# ['PL11462380436218108192209769',
#  'PL68993998198602899323173401',
#  'PL10681175466306981734162786',
#  'PL18357348816848270635281232',
#  'PL62539178393034479371408649',
#  'PL94019190105333137692760549',
#  'PL26198437171737832118498390',
#  'PL92423876370750359655316762',
#  'PL92850233950586676619619528']
